# %%
# !pip install seaborn pandas matplotlib scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 2.8 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.1 MB 3.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.1 MB 3.4 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 3.4 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 3.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.1 MB 3.6 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 3.7 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.1 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 3.8 MB/s eta 0:00:00
# ...

# %%
# !pip install scipy openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\PC\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# Leitura dos dados 
file = 'C:/Users/PC/Downloads/pluscard.xlsx'
df = pd.read_excel(file)

# %% [markdown]
# ###  Formulação do Problema
#
# * Qual é a variável dependente do modelo?
#   * R -
# * O objetivo é explicativo, preditivo ou ambos?
#   * R -
# * Quais variáveis você espera que aumentem a fatura?
#   * R -
# * Justifique economicamente suas hipóteses.
#   * R-
